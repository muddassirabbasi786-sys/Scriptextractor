# %% [markdown]
# # VibeVoice Colab
# ### 🏷️ **Credits & License**
#
# * 🔗 [VibeVoice GitHub Repository](https://github.com/microsoft/VibeVoice)
# * 🤗 [VibeVoice on Hugging Face](https://huggingface.co/microsoft/VibeVoice-1.5B)
# * 📄 **License**: Provided under the [MIT License](https://github.com/microsoft/VibeVoice/blob/main/LICENSE)
#
# ### ⚠️ **Usage Disclaimer**
#
# This tool enables **AI-generated podcast creation** using cloned voices. While it can be a powerful resource for storytelling, education, and creative projects, it also carries risks if misused. By using this tool, you agree to the following guidelines:
#
# * **No Misrepresentation**: Do not use cloned voices to impersonate real people or mislead listeners into believing AI-generated voices are authentic recordings without disclosure.
# * **Transparency**: Clearly disclose when podcast content has been generated with AI, including synthetic voices or AI-written scripts.
# * **No Harmful Content**: Do not produce or distribute content that promotes hate, harassment, misinformation, defamation, or any form of harmful/deceptive material.
# * **Legal Compliance**: Ensure all use of this tool complies with copyright laws, data protection regulations, and all applicable legal and ethical standards.
# * **Respect for Consent**: Do not replicate or publish anyone’s voice without explicit permission.
#
# > ⚖️ **Legal Responsibility**
#
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
# @title Install VibeVoice

# %cd /content/


# !git clone https://github.com/microsoft/VibeVoice.git
# Download colab.py
# %cd /content/VibeVoice/demo
# !wget https://raw.githubusercontent.com/NeuralFalconYT/VibeVoice/refs/heads/main/demo/colab.py


# (Optional) If you experience compatibility issues with the latest version, you can use a pinned fork instead:
# !git clone https://github.com/NeuralFalconYT/VibeVoice.git



# %cd /content/VibeVoice/
# !pip install -e .
# !pip install pydub>=0.25.1

from IPython.display import clear_output
clear_output()

# %%
#@title Run Official Gradio UI
# !python /content/VibeVoice/demo/gradio_demo.py --model_path "microsoft/VibeVoice-1.5B" --inference_steps 10 --share

# %%
#@title Automatically save podcast to your Google Drive [Optional]
Enable_Drive_Save= False  # @param {type: "boolean"}
if Enable_Drive_Save:
  from google.colab import drive
  drive.mount('/content/gdrive/')

# %%
#@title Run VibeVoice Podcast
# !python /content/VibeVoice/demo/colab.py --model_path microsoft/VibeVoice-1.5B --inference_steps 10 --debug --share
# Out:
# 2026-01-08 22:51:30.404174: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767912690.420518    1256 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767912690.425358    1256 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767912690.438113    1256 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767912690.438137    1256 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767912690.438141    1256 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767912690.438146    1256 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-08 22:51:30.442026: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:vibevoice.modular.modular_vibevoice_tokenizer:APEX FusedRMSNorm not available, using native implementation
# 📂 Download directory: /content/VibeVoice/VibeVoice-1.5B
# 📦 Found 9 files in repo 'microsoft/VibeVoice-1.5B'. Checking cache ...
# Processing files:   0% 0/9 [00:00<?, ?file/s]
# .gitattributes:   0% 0.00/1.57k [00:00<?, ?B/s]
# .gitattributes: 16.0kB [00:00, 119kB/s]
# ⬇️ Downloaded: .gitattributes
# Processing files:  11% 1/9 [00:00<00:03,  2.54file/s]
# README.md:   0% 0.00/7.10k [00:00<?, ?B/s]
# README.md: 16.0kB [00:00, 121kB/s]
# ⬇️ Downloaded: README.md
# Processing files:  22% 2/9 [00:00<00:02,  3.14file/s]
# config.json:   0% 0.00/2.70k [00:00<?, ?B/s]
# config.json: 16.0kB [00:00, 130kB/s]
# ⬇️ Downloaded: config.json
# Processing files:  33% 3/9 [00:00<00:01,  3.45file/s]
# Fig1.png:   0% 0.00/150k [00:00<?, ?B/s]
# Fig1.png: 160kB [00:00, 1.12MB/s]
# ⬇️ Downloaded: Fig1.png
# Processing files:  44% 4/9 [00:01<00:01,  3.32file/s]
# model-00001-of-00003.safetensors:   0% 0.00/1.84G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 8.00k/1.84G [00:00<8:51:49, 61.9kB/s]
# model-00001-of-00003.safetensors:   1% 15.8M/1.84G [00:00<00:22, 86.0MB/s]
# model-00001-of-00003.safetensors:   2% 42.2M/1.84G [00:00<00:11, 162MB/s]
# model-00001-of-00003.safetensors:   4% 69.5M/1.84G [00:00<00:09, 207MB/s]
# model-00001-of-00003.safetensors:   5% 98.8M/1.84G [00:00<00:07, 241MB/s]
# model-00001-of-00003.safetensors:   7% 123M/1.84G [00:00<00:07, 245MB/s]
# model-00001-of-00003.safetensors:   8% 151M/1.84G [00:00<00:06, 262MB/s]
# model-00001-of-00003.safetensors:  10% 181M/1.84G [00:00<00:06, 277MB/s]
# model-00001-of-00003.safetensors:  11% 211M/1.84G [00:00<00:06, 288MB/s]
# model-00001-of-00003.safetensors:  13% 238M/1.84G [00:01<00:06, 269MB/s]
# model-00001-of-00003.safetensors:  14% 267M/1.84G [00:01<00:06, 279MB/s]
# model-00001-of-00003.safetensors:  16% 298M/1.84G [00:01<00:05, 291MB/s]
# model-00001-of-00003.safetensors:  17% 329M/1.84G [00:01<00:05, 301MB/s]
# model-00001-of-00003.safetensors:  19% 361M/1.84G [00:01<00:05, 310MB/s]
# model-00001-of-00003.safetensors:  21% 390M/1.84G [00:01<00:05, 306MB/s]
# model-00001-of-00003.safetensors:  22% 422M/1.84G [00:01<00:04, 314MB/s]
# model-00001-of-00003.safetensors:  24% 456M/1.84G [00:01<00:04, 326MB/s]
# model-00001-of-00003.safetensors:  26% 490M/1.84G [00:01<00:04, 334MB/s]
# model-00001-of-00003.safetensors:  28% 522M/1.84G [00:01<00:04, 336MB/s]
# model-00001-of-00003.safetensors:  29% 554M/1.84G [00:02<00:04, 326MB/s]
# model-00001-of-00003.safetensors:  31% 585M/1.84G [00:02<00:04, 314MB/s]
# model-00001-of-00003.safetensors:  33% 615M/1.84G [00:02<00:04, 311MB/s]
# model-00001-of-00003.safetensors:  34% 645M/1.84G [00:02<00:04, 285MB/s]
# model-00001-of-00003.safetensors:  36% 674M/1.84G [00:02<00:04, 290MB/s]
# model-00001-of-00003.safetensors:  37% 702M/1.84G [00:02<00:04, 277MB/s]
# model-00001-of-00003.safetensors:  39% 729M/1.84G [00:02<00:04, 248MB/s]
# model-00001-of-00003.safetensors:  40% 760M/1.84G [00:02<00:04, 270MB/s]
# model-00001-of-00003.safetensors:  42% 787M/1.84G [00:02<00:04, 268MB/s]
# model-00001-of-00003.safetensors:  43% 813M/1.84G [00:03<00:04, 253MB/s]
# model-00001-of-00003.safetensors:  44% 838M/1.84G [00:03<00:04, 253MB/s]
# model-00001-of-00003.safetensors:  46% 862M/1.84G [00:03<00:04, 226MB/s]
# model-00001-of-00003.safetensors:  47% 884M/1.84G [00:03<00:04, 220MB/s]
# model-00001-of-00003.safetensors:  49% 915M/1.84G [00:03<00:04, 247MB/s]
# model-00001-of-00003.safetensors:  50% 939M/1.84G [00:05<00:26, 37.7MB/s]
# model-00001-of-00003.safetensors:  51% 956M/1.84G [00:05<00:21, 45.2MB/s]
# model-00001-of-00003.safetensors:  52% 979M/1.84G [00:05<00:15, 59.8MB/s]
# model-00001-of-00003.safetensors:  54% 0.99G/1.84G [00:06<00:10, 85.5MB/s]
# model-00001-of-00003.safetensors:  55% 1.02G/1.84G [00:06<00:07, 116MB/s]
# model-00001-of-00003.safetensors:  57% 1.04G/1.84G [00:06<00:06, 137MB/s]
# model-00001-of-00003.safetensors:  58% 1.07G/1.84G [00:06<00:05, 161MB/s]
# model-00001-of-00003.safetensors:  60% 1.10G/1.84G [00:06<00:04, 192MB/s]
# model-00001-of-00003.safetensors:  61% 1.13G/1.84G [00:06<00:03, 221MB/s]
# model-00001-of-00003.safetensors:  63% 1.16G/1.84G [00:06<00:02, 245MB/s]
# model-00001-of-00003.safetensors:  65% 1.19G/1.84G [00:06<00:02, 266MB/s]
# model-00001-of-00003.safetensors:  66% 1.22G/1.84G [00:06<00:02, 285MB/s]
# model-00001-of-00003.safetensors:  68% 1.25G/1.84G [00:06<00:02, 289MB/s]
# model-00001-of-00003.safetensors:  70% 1.28G/1.84G [00:07<00:01, 304MB/s]
# model-00001-of-00003.safetensors:  71% 1.31G/1.84G [00:07<00:01, 313MB/s]
# model-00001-of-00003.safetensors:  73% 1.35G/1.84G [00:07<00:01, 322MB/s]
# model-00001-of-00003.safetensors:  75% 1.38G/1.84G [00:07<00:01, 307MB/s]
# model-00001-of-00003.safetensors:  77% 1.41G/1.84G [00:07<00:01, 316MB/s]
# model-00001-of-00003.safetensors:  78% 1.44G/1.84G [00:07<00:01, 305MB/s]
# model-00001-of-00003.safetensors:  80% 1.47G/1.84G [00:07<00:01, 289MB/s]
# model-00001-of-00003.safetensors:  81% 1.50G/1.84G [00:09<00:08, 42.8MB/s]
# model-00001-of-00003.safetensors:  83% 1.52G/1.84G [00:09<00:06, 55.4MB/s]
# model-00001-of-00003.safetensors:  84% 1.54G/1.84G [00:10<00:04, 64.9MB/s]
# model-00001-of-00003.safetensors:  85% 1.56G/1.84G [00:10<00:04, 64.4MB/s]
# model-00001-of-00003.safetensors:  86% 1.59G/1.84G [00:10<00:03, 87.5MB/s]
# model-00001-of-00003.safetensors:  88% 1.62G/1.84G [00:10<00:02, 113MB/s]
# model-00001-of-00003.safetensors:  89% 1.64G/1.84G [00:10<00:01, 141MB/s]
# model-00001-of-00003.safetensors:  91% 1.67G/1.84G [00:10<00:01, 147MB/s]
# model-00001-of-00003.safetensors:  92% 1.70G/1.84G [00:11<00:00, 183MB/s]
# model-00001-of-00003.safetensors:  94% 1.73G/1.84G [00:11<00:00, 212MB/s]
# model-00001-of-00003.safetensors:  96% 1.76G/1.84G [00:11<00:00, 234MB/s]
# model-00001-of-00003.safetensors:  97% 1.79G/1.84G [00:11<00:00, 249MB/s]
# model-00001-of-00003.safetensors: 1.84GB [00:11, 171MB/s]
# ⬇️ Downloaded: model-00001-of-00003.safetensors
# Processing files:  56% 5/9 [00:12<00:17,  4.41s/file]
# model-00002-of-00003.safetensors:   0% 0.00/1.85G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 8.00k/1.85G [00:00<9:16:22, 59.4kB/s]
# model-00002-of-00003.safetensors:   1% 20.4M/1.85G [00:00<00:18, 109MB/s]
# model-00002-of-00003.safetensors:   3% 59.1M/1.85G [00:00<00:08, 234MB/s]
# model-00002-of-00003.safetensors:   5% 92.7M/1.85G [00:00<00:06, 278MB/s]
# model-00002-of-00003.safetensors:   6% 121M/1.85G [00:00<00:06, 279MB/s]
# model-00002-of-00003.safetensors:   8% 154M/1.85G [00:00<00:06, 302MB/s]
# model-00002-of-00003.safetensors:  10% 184M/1.85G [00:00<00:05, 306MB/s]
# model-00002-of-00003.safetensors:  11% 214M/1.85G [00:04<01:04, 27.5MB/s]
# model-00002-of-00003.safetensors:  12% 234M/1.85G [00:04<00:50, 34.3MB/s]
# model-00002-of-00003.safetensors:  14% 271M/1.85G [00:04<00:32, 52.1MB/s]
# model-00002-of-00003.safetensors:  16% 312M/1.85G [00:04<00:21, 77.8MB/s]
# model-00002-of-00003.safetensors:  18% 341M/1.85G [00:04<00:16, 96.5MB/s]
# model-00002-of-00003.safetensors:  20% 372M/1.85G [00:04<00:13, 122MB/s]
# model-00002-of-00003.safetensors:  21% 406M/1.85G [00:04<00:10, 155MB/s]
# model-00002-of-00003.safetensors:  23% 437M/1.85G [00:04<00:08, 177MB/s]
# model-00002-of-00003.safetensors:  25% 467M/1.85G [00:04<00:07, 204MB/s]
# model-00002-of-00003.safetensors:  27% 501M/1.85G [00:05<00:06, 236MB/s]
# model-00002-of-00003.safetensors:  28% 536M/1.85G [00:05<00:05, 265MB/s]
# model-00002-of-00003.safetensors:  30% 570M/1.85G [00:05<00:04, 289MB/s]
# model-00002-of-00003.safetensors:  32% 603M/1.85G [00:05<00:04, 303MB/s]
# model-00002-of-00003.safetensors:  34% 638M/1.85G [00:05<00:04, 320MB/s]
# model-00002-of-00003.safetensors:  36% 672M/1.85G [00:05<00:04, 294MB/s]
# model-00002-of-00003.safetensors:  37% 702M/1.85G [00:05<00:04, 285MB/s]
# model-00002-of-00003.safetensors:  39% 731M/1.85G [00:05<00:04, 270MB/s]
# model-00002-of-00003.safetensors:  40% 758M/1.85G [00:05<00:04, 272MB/s]
# model-00002-of-00003.safetensors:  42% 785M/1.85G [00:06<00:04, 269MB/s]
# model-00002-of-00003.safetensors:  43% 811M/1.85G [00:08<00:27, 41.2MB/s]
# model-00002-of-00003.safetensors:  44% 830M/1.85G [00:08<00:22, 49.8MB/s]
# model-00002-of-00003.safetensors:  46% 864M/1.85G [00:08<00:14, 72.7MB/s]
# model-00002-of-00003.safetensors:  47% 897M/1.85G [00:08<00:10, 99.0MB/s]
# model-00002-of-00003.safetensors:  49% 923M/1.85G [00:08<00:08, 117MB/s]
# model-00002-of-00003.safetensors:  50% 952M/1.85G [00:08<00:06, 144MB/s]
# model-00002-of-00003.safetensors:  52% 978M/1.85G [00:08<00:06, 158MB/s]
# model-00002-of-00003.safetensors:  53% 0.98G/1.85G [00:08<00:05, 167MB/s]
# model-00002-of-00003.safetensors:  54% 1.00G/1.85G [00:09<00:05, 176MB/s]
# model-00002-of-00003.safetensors:  56% 1.03G/1.85G [00:09<00:04, 195MB/s]
# model-00002-of-00003.safetensors:  57% 1.05G/1.85G [00:09<00:04, 208MB/s]
# model-00002-of-00003.safetensors:  58% 1.07G/1.85G [00:09<00:03, 223MB/s]
# model-00002-of-00003.safetensors:  59% 1.10G/1.85G [00:09<00:03, 233MB/s]
# model-00002-of-00003.safetensors:  61% 1.12G/1.85G [00:09<00:03, 235MB/s]
# model-00002-of-00003.safetensors:  62% 1.15G/1.85G [00:09<00:03, 239MB/s]
# model-00002-of-00003.safetensors:  63% 1.17G/1.85G [00:09<00:02, 245MB/s]
# model-00002-of-00003.safetensors:  65% 1.19G/1.85G [00:09<00:02, 241MB/s]
# model-00002-of-00003.safetensors:  66% 1.22G/1.85G [00:10<00:02, 238MB/s]
# model-00002-of-00003.safetensors:  67% 1.24G/1.85G [00:10<00:02, 232MB/s]
# model-00002-of-00003.safetensors:  68% 1.26G/1.85G [00:10<00:04, 151MB/s]
# model-00002-of-00003.safetensors:  70% 1.28G/1.85G [00:10<00:03, 174MB/s]
# model-00002-of-00003.safetensors:  71% 1.31G/1.85G [00:10<00:02, 200MB/s]
# model-00002-of-00003.safetensors:  73% 1.34G/1.85G [00:10<00:02, 227MB/s]
# model-00002-of-00003.safetensors:  74% 1.36G/1.85G [00:10<00:02, 222MB/s]
# model-00002-of-00003.safetensors:  75% 1.39G/1.85G [00:10<00:02, 209MB/s]
# model-00002-of-00003.safetensors:  77% 1.41G/1.85G [00:11<00:01, 232MB/s]
# model-00002-of-00003.safetensors:  78% 1.44G/1.85G [00:11<00:01, 242MB/s]
# model-00002-of-00003.safetensors:  79% 1.46G/1.85G [00:14<00:16, 25.5MB/s]
# model-00002-of-00003.safetensors:  80% 1.48G/1.85G [00:14<00:11, 33.5MB/s]
# model-00002-of-00003.safetensors:  82% 1.52G/1.85G [00:14<00:06, 50.9MB/s]
# model-00002-of-00003.safetensors:  84% 1.55G/1.85G [00:14<00:04, 75.1MB/s]
# model-00002-of-00003.safetensors:  86% 1.58G/1.85G [00:14<00:03, 94.0MB/s]
# model-00002-of-00003.safetensors:  87% 1.61G/1.85G [00:14<00:02, 114MB/s]
# model-00002-of-00003.safetensors:  89% 1.64G/1.85G [00:15<00:01, 142MB/s]
# model-00002-of-00003.safetensors:  90% 1.67G/1.85G [00:15<00:01, 169MB/s]
# model-00002-of-00003.safetensors:  92% 1.70G/1.85G [00:15<00:00, 199MB/s]
# model-00002-of-00003.safetensors:  94% 1.73G/1.85G [00:15<00:00, 229MB/s]
# model-00002-of-00003.safetensors:  95% 1.76G/1.85G [00:15<00:00, 242MB/s]
# model-00002-of-00003.safetensors:  97% 1.79G/1.85G [00:15<00:00, 255MB/s]
# model-00002-of-00003.safetensors:  98% 1.82G/1.85G [00:15<00:00, 273MB/s]
# model-00002-of-00003.safetensors: 1.85GB [00:15, 126MB/s]
# ⬇️ Downloaded: model-00002-of-00003.safetensors
# Processing files:  67% 6/9 [00:28<00:25,  8.34s/file]
# model-00003-of-00003.safetensors:   0% 0.00/1.35G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0% 8.00k/1.35G [00:00<7:26:08, 54.2kB/s]
# model-00003-of-00003.safetensors:   1% 19.2M/1.35G [00:00<00:14, 98.0MB/s]
# model-00003-of-00003.safetensors:   3% 43.1M/1.35G [00:00<00:08, 160MB/s]
# model-00003-of-00003.safetensors:   5% 72.2M/1.35G [00:00<00:06, 214MB/s]
# model-00003-of-00003.safetensors:   7% 100M/1.35G [00:00<00:05, 242MB/s]
# model-00003-of-00003.safetensors:   9% 125M/1.35G [00:00<00:05, 222MB/s]
# model-00003-of-00003.safetensors:  11% 155M/1.35G [00:00<00:05, 251MB/s]
# model-00003-of-00003.safetensors:  13% 185M/1.35G [00:00<00:04, 271MB/s]
# model-00003-of-00003.safetensors:  16% 217M/1.35G [00:01<00:05, 243MB/s]
# model-00003-of-00003.safetensors:  18% 249M/1.35G [00:01<00:04, 269MB/s]
# model-00003-of-00003.safetensors:  20% 279M/1.35G [00:01<00:04, 280MB/s]
# model-00003-of-00003.safetensors:  22% 307M/1.35G [00:01<00:04, 271MB/s]
# model-00003-of-00003.safetensors:  24% 333M/1.35G [00:01<00:04, 269MB/s]
# model-00003-of-00003.safetensors:  26% 359M/1.35G [00:01<00:04, 244MB/s]
# model-00003-of-00003.safetensors:  28% 389M/1.35G [00:01<00:04, 261MB/s]
# model-00003-of-00003.safetensors:  30% 414M/1.35G [00:01<00:04, 211MB/s]
# model-00003-of-00003.safetensors:  32% 445M/1.35G [00:01<00:04, 239MB/s]
# model-00003-of-00003.safetensors:  34% 476M/1.35G [00:02<00:03, 261MB/s]
# model-00003-of-00003.safetensors:  36% 503M/1.35G [00:02<00:03, 265MB/s]
# model-00003-of-00003.safetensors:  38% 530M/1.35G [00:02<00:03, 267MB/s]
# model-00003-of-00003.safetensors:  40% 556M/1.35G [00:02<00:03, 258MB/s]
# model-00003-of-00003.safetensors:  42% 581M/1.35G [00:04<00:21, 38.3MB/s]
# model-00003-of-00003.safetensors:  44% 611M/1.35G [00:04<00:15, 53.6MB/s]
# model-00003-of-00003.safetensors:  46% 641M/1.35G [00:04<00:10, 72.6MB/s]
# model-00003-of-00003.safetensors:  49% 672M/1.35G [00:04<00:07, 96.7MB/s]
# model-00003-of-00003.safetensors:  51% 698M/1.35G [00:05<00:06, 117MB/s]
# model-00003-of-00003.safetensors:  52% 726M/1.35G [00:05<00:04, 141MB/s]
# model-00003-of-00003.safetensors:  55% 755M/1.35G [00:05<00:03, 170MB/s]
# model-00003-of-00003.safetensors:  57% 790M/1.35G [00:05<00:02, 207MB/s]
# model-00003-of-00003.safetensors:  59% 820M/1.35G [00:05<00:02, 232MB/s]
# model-00003-of-00003.safetensors:  61% 850M/1.35G [00:05<00:02, 226MB/s]
# model-00003-of-00003.safetensors:  63% 877M/1.35G [00:05<00:02, 226MB/s]
# model-00003-of-00003.safetensors:  65% 902M/1.35G [00:05<00:02, 227MB/s]
# model-00003-of-00003.safetensors:  67% 927M/1.35G [00:05<00:02, 231MB/s]
# model-00003-of-00003.safetensors:  69% 951M/1.35G [00:06<00:02, 221MB/s]
# model-00003-of-00003.safetensors:  70% 974M/1.35G [00:06<00:01, 226MB/s]
# model-00003-of-00003.safetensors:  72% 996M/1.35G [00:06<00:01, 228MB/s]
# model-00003-of-00003.safetensors:  74% 0.99G/1.35G [00:06<00:01, 230MB/s]
# model-00003-of-00003.safetensors:  75% 1.02G/1.35G [00:06<00:01, 232MB/s]
# model-00003-of-00003.safetensors:  77% 1.04G/1.35G [00:06<00:01, 234MB/s]
# model-00003-of-00003.safetensors:  79% 1.06G/1.35G [00:06<00:01, 242MB/s]
# model-00003-of-00003.safetensors:  80% 1.09G/1.35G [00:06<00:01, 243MB/s]
# model-00003-of-00003.safetensors:  82% 1.11G/1.35G [00:06<00:01, 232MB/s]
# model-00003-of-00003.safetensors:  84% 1.13G/1.35G [00:06<00:00, 235MB/s]
# model-00003-of-00003.safetensors:  86% 1.16G/1.35G [00:07<00:00, 248MB/s]
# model-00003-of-00003.safetensors:  88% 1.19G/1.35G [00:07<00:00, 262MB/s]
# model-00003-of-00003.safetensors:  90% 1.21G/1.35G [00:07<00:00, 243MB/s]
# model-00003-of-00003.safetensors:  91% 1.23G/1.35G [00:07<00:00, 242MB/s]
# model-00003-of-00003.safetensors:  93% 1.26G/1.35G [00:07<00:00, 247MB/s]
# model-00003-of-00003.safetensors:  95% 1.28G/1.35G [00:07<00:00, 243MB/s]
# model-00003-of-00003.safetensors:  97% 1.30G/1.35G [00:07<00:00, 235MB/s]
# model-00003-of-00003.safetensors:  98% 1.33G/1.35G [00:07<00:00, 220MB/s]
# model-00003-of-00003.safetensors: 1.35GB [00:07, 183MB/s]
# ⬇️ Downloaded: model-00003-of-00003.safetensors
# Processing files:  78% 7/9 [00:37<00:16,  8.29s/file]
# model.safetensors.index.json:   0% 0.00/120k [00:00<?, ?B/s]
# model.safetensors.index.json: 128kB [00:00, 780kB/s]
# ⬇️ Downloaded: model.safetensors.index.json
# Processing files:  89% 8/9 [00:37<00:05,  5.75s/file]
# preprocessor_config.json:   0% 0.00/351 [00:00<?, ?B/s]
# preprocessor_config.json: 16.0kB [00:00, 126kB/s]
# ⬇️ Downloaded: preprocessor_config.json
# Processing files: 100% 9/9 [00:37<00:00,  4.19s/file]
# 🎙️ Initializing VibeVoice ...
# Loading processor & model from /content/VibeVoice/VibeVoice-1.5B
# tokenizer_config.json: 7.23kB [00:00, 31.6MB/s]
# vocab.json: 2.78MB [00:00, 66.9MB/s]
# merges.txt: 1.67MB [00:00, 127MB/s]
# tokenizer.json: 7.03MB [00:00, 194MB/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Qwen2Tokenizer'.
# The class this function is called from is 'VibeVoiceTextTokenizerFast'.
# Loading checkpoint shards: 100% 3/3 [00:22<00:00,  7.52s/it]
# Language model attention: sdpa
# Found 9 voice files in /content/VibeVoice/demo/voices
# 🚀 Launching Gradio Demo...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://1ce0bf01af1bb2214f.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Found 10 voice files in /content/VibeVoice/demo/voices
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
#
# ✨ Full generation successful!
# 🎵 Audio: ./podcast_audio/hi_everyone_im_alice_and_i_c02f05.wav
# 📄 Timestamps: ./podcast_audio/hi_everyone_im_alice_and_i_c02f05.json
#
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
#
# ✨ Full generation successful!
# 🎵 Audio: ./podcast_audio/hi_everyone_im_alice_and_i_22712a.wav
# 📄 Timestamps: ./podcast_audio/hi_everyone_im_alice_and_i_22712a.json
#
# Found 11 voice files in /content/VibeVoice/demo/voices
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
#
# ✨ Full generation successful!
# 🎵 Audio: ./podcast_audio/hi_everyone_im_alice_and_i_ebaed9.wav
# 📄 Timestamps: ./podcast_audio/hi_everyone_im_alice_and_i_ebaed9.json
#
# Generating (active: 1/1):   4% 20/518 [00:05<01:46,  4.69it/s]
